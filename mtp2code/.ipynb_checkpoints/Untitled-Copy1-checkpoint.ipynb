# %%
import zipfile
import os
from os import error, walk


from bs4 import BeautifulSoup
import re

# %% [markdown]
# # Loading

# %%
# Converting Epub books to folders containing HTML
# ---------------------------------------------------------------------

# folder path of epub books you want to extract images from
# epub_folder = "C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/"


# for root, dirs, files in os.walk(epub_folder):
#     for file in files:
#         if file.endswith(".epub"):
#             folder_name = root+"/"+file[:-5]
#             file_name = root+"/"+file
#             print(folder_name)
#             print(file_name)
#             with zipfile.ZipFile(file_name, 'r') as zip_ref:
#                 zip_ref.extractall(folder_name)

# ----------------------------------------------------------------------

classes_folders = []
classes_folders_path = "C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub"

for file in os.listdir(classes_folders_path):
    d = os.path.join(classes_folders_path, file).replace("\\","/")
    if os.path.isdir(d):
        classes_folders.append(d)

print(f"len of classes_folders = {len(classes_folders)}")
for classes_folder in classes_folders:
    print(classes_folder)

textbooks_html_files = []
for classes_folder in classes_folders:
    for file in os.listdir(classes_folder):
        d = os.path.join(classes_folder, file).replace("\\","/")
        if os.path.isdir(d):
            html_files = os.listdir(d+"/OEBPS/Text/")
            html_files_path = []
            for html in html_files:
                html_files_path.append(d+"/OEBPS/Text/"+html)
            largest_html_file = max(html_files_path, key=os.path.getsize)
            textbooks_html_files.append(largest_html_file)

print(f"len of textbaooks_folders = {len(textbooks_html_files)}")
for html in textbooks_html_files:
    print(html)

# %%
def remove_non_ascii(text):
    return ''.join([i if ord(i) < 128 else ' ' for i in text])



extensions_list = []


for filename in textbooks_html_files:
    try:
        # with open(filename, encoding="utf8") as fp:
        fp = open(filename, encoding="utf8")
        print("++++++++++++++++++++++++++++   START   +++++++++++++++++++++")
        print(filename)
    except:
        print("***************  Error while opening file   ***************")
        print(filename)
        print("************************************************************")
    extension = filename.split(".")[-1]
    if extension not in extensions_list:
        extensions_list.append(extension)
    if extension == "xhtml":
        try:
            print("@@@@@@@@@@@@   XML parser")
            soup = BeautifulSoup(fp, 'lxml-xml')
        except Exception as e:
            print(" ^^^^^^^^^^^ Error while html parsing ^^^^^^^^^^^^^^^^^^^")
            # print(filename)
            print(e)
            print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")

    elif extension == "html":
        try:
            # soup = BeautifulSoup(fp, 'xml')
            print("@@@@@@@@@@@@   HTML parser")
            soup = BeautifulSoup(fp, 'lxml')
        except Exception as e:
            print(" ^^^^^^^^^^^ Error while html parsing ^^^^^^^^^^^^^^^^^^^")
            # print(filename)
            print(e)
            print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")

    all_fig = soup.find_all(string=re.compile("^Fig"))
    i = 1
    max_caption_words = 60
    min_caption_words = 6
    
    def extract_lastfig(txt):
        txt = remove_non_ascii(txt).strip().replace("\n"," ")
        last_index = [_.start() for _ in re.finditer(r"Fig", txt)][-1]
        return txt[last_index:]

    for fig in all_fig:
        print("------- fig  "+str(i)+"   --------")
        
        caption_parent_text = extract_lastfig(fig.parent.parent.get_text())
        caption_grandparent_text = extract_lastfig(fig.parent.parent.parent.get_text())
        fig_text = extract_lastfig(fig)
        if len(fig_text.split()) >= max_caption_words:
            continue
        elif len(fig_text.split()) >= min_caption_words:
            print(f"fig\nlength = {len(fig.split())}")
            print(fig_text)
        elif len(caption_parent_text.split()) >= max_caption_words:
            print(f"fig\nlength = {len(fig.split())}")
            print(fig_text)
        elif len(caption_grandparent_text.split()) >= max_caption_words:
            print(f" fig + parent\n length = {len(caption_parent_text.split())}")
            print(caption_parent_text)
        else:
            print( f"fig + grandparent \nlength = {len(caption_grandparent_text.split())}")
            print(caption_grandparent_text)

        same_el_img = fig.parent.find_all("img")
        prev_img = fig.parent.find_previous("img")
        if same_el_img == []:
            if prev_img == None:
                print("No image found")
            else:
                print("previous image = "+ prev_img["src"])
        else:
            print("same tag image = "+ same_el_img[0]["src"])
        i = i + 1
    print("++++++++++++++++++++++++++++   END   +++++++++++++++++++++\n")

extension_file = open("extension_list.txt", "w")
extension_file.write(str(extensions_list))
extension_file.close()


# for filename in all_files:
#     print("++++++++++++++++++++++++++++   START   +++++++++++++++++++++")
#     print(filename)
#     with open(filename) as fp:
#         soup = BeautifulSoup(fp, 'xml')
#         all_p = soup.find_all('p', "caption")
#         all_img = soup.find_all('img')
#         all_cap = soup.find_all(attrs={"class": "caption"})

#         i = 1
#         for el in all_cap:
#             caption = el.get_text()
#             caption = caption.replace("\n","")
#             # caption = caption.replace(" ","")
#             if caption=="":
#                 continue
#             print("  ---------------------------   "+str(i)+"  -------------------------- ")
#             print(caption)
#             print("   ")
#             same_el_img = el.find_all("img")
#             prev_img = el.find_previous("img")
#             if same_el_img == []:    
#                 print(prev_img["src"])
#             else:
#                 print(same_el_img[0]["src"])
#             print("   ")
#             i = i+1
#             print("  ******************************************************************* ")
    
#     print("++++++++++++++++++++++++++++   END   +++++++++++++++++++++\n")
# Out:
# len of classes_folders = 13
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science
# len of textbooks_folders = 209
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/16_5240_1/OEBPS/Text/Chapter-1.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/17_5240_2/OEBPS/Text/Untitled-4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/18_5240_3/OEBPS/Text/Chapter-3.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/19_5240_4/OEBPS/Text/Chapter-4.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/20_5240_5/OEBPS/Text/Chapter-5.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/21_5240_6/OEBPS/Text/Chapter-6.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/22_5240_7/OEBPS/Text/Chapter-7.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/23_5240_8/OEBPS/Text/Chapter-8.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/24_5240_9/OEBPS/Text/Chapter-9.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/25_5240_10/OEBPS/Text/Chapter-10.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/26_5240_11/OEBPS/Text/Chapter-11.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/27_5240_12/OEBPS/Text/Chapter-12.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/28_5240_13/OEBPS/Text/Chapter-13.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/29_5240_14/OEBPS/Text/Chapter-14.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/30_5240_15/OEBPS/Text/Chapter-15.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/31_5240_16/OEBPS/Text/Chapter-16.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/100_5156_17/OEBPS/Text/ch-17.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/101_5156_18/OEBPS/Text/ch-18.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/102_5156_19/OEBPS/Text/ch-19.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/103_5156_20/OEBPS/Text/ch-20.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/104_5156_21/OEBPS/Text/ch-21.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/105_5156_22/OEBPS/Text/ch-22.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/84_5156_1/OEBPS/Text/ch-1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/85_5156_2/OEBPS/Text/ch-2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/86_5156_3/OEBPS/Text/ch-3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/87_5156_4/OEBPS/Text/ch-4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/88_5156_5/OEBPS/Text/ch-5.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/89_5156_6/OEBPS/Text/ch-6.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/90_5156_7/OEBPS/Text/ch-7.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/91_5156_8/OEBPS/Text/ch-8.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/92_5156_9/OEBPS/Text/ch-9.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/93_5156_10/OEBPS/Text/Chapter 10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/94_5156_11/OEBPS/Text/ch-11.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/95_5156_12/OEBPS/Text/ch-12.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/96_5156_13/OEBPS/Text/ch-13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/97_5156_14/OEBPS/Text/ch-14.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/98_5156_15/OEBPS/Text/ch-15.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_biology/99_5156_16/OEBPS/Text/ch-16.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/17_5161_1/OEBPS/Text/Unit-1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/18_5161_2/OEBPS/Text/Unit-2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/19_5161_3/OEBPS/Text/Unit-3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/20_5161_4/OEBPS/Text/Unit-4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/21_5161_5/OEBPS/Text/Unit-5.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/22_5161_6/OEBPS/Text/Unit-6.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/23_5161_7/OEBPS/Text/Unit-7.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/39_5163_8/OEBPS/Text/ch8.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/40_5163_9/OEBPS/Text/ch9.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/41_5163_10/OEBPS/Text/ch10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/42_5163_11/OEBPS/Text/ch11.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/43_5163_12/OEBPS/Text/ch12.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/44_5163_13/OEBPS/Text/ch13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_chemistry/45_5163_14/OEBPS/Text/ch14.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/10_5215_10/OEBPS/Text/Chapter_10 FINAL  04.01.06.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/11_5215_11/OEBPS/Text/Conic Section FINAL 05.01.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/12_5215_12/OEBPS/Text/chapter-12 FINAL -02.01.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/13_5215_13/OEBPS/Text/13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/14_5215_14/OEBPS/Text/Mathematical Reasoning FINAL 05.01.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/15_5215_15/OEBPS/Text/15.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/16_5215_16/OEBPS/Text/16.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/1_5215_1/OEBPS/Text/Chapter 1.html
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/2_5215_2/OEBPS/Text/ch2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/3_5215_3/OEBPS/Text/ch3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/4_5215_4/OEBPS/Text/Ch_04FINAL_02.01.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/5_5215_5/OEBPS/Text/Ch_05 FINAL _04.01.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/6_5215_6/OEBPS/Text/Linear Ineaqualities FINAL 03.01.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/7_5215_7/OEBPS/Text/Permutation and Combinations FINAL  04.01.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/8_5215_8/OEBPS/Text/Binomial Theorem FINAL 06.01.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_maths/9_5215_9/OEBPS/Text/Sequence _ Series Final  03.01.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/24_5224_1/OEBPS/Text/Chapter_1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/25_5224_2/OEBPS/Text/Chapter 2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/26_5224_3/OEBPS/Text/Chapter 3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/27_5224_4/OEBPS/Text/Chapter 4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/28_5224_5/OEBPS/Text/Chapter_5.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/29_5224_6/OEBPS/Text/Chapter 6.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/30_5224_7/OEBPS/Text/Chapter 7.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/31_5224_8/OEBPS/Text/CHAPTER-8.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/32_5226_9/OEBPS/Text/Ch_09.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/33_5226_10/OEBPS/Text/Ch_10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/34_5226_11/OEBPS/Text/ch_11.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/35_5226_12/OEBPS/Text/Ch_12.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/36_5226_13/OEBPS/Text/Ch_13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/37_5226_14/OEBPS/Text/Ch_14.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_11_physics/38_5226_15/OEBPS/Text/Ch_15.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/106_5157_1/OEBPS/Text/Chapter-1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/107_5157_2/OEBPS/Text/Chapter-2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/108_5157_3/OEBPS/Text/Chapter-3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/109_5157_4/OEBPS/Text/Chapter-4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/110_5157_5/OEBPS/Text/Chapter-5.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/111_5157_6/OEBPS/Text/Chapter-6.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/112_5157_7/OEBPS/Text/Chapter-7.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/113_5157_8/OEBPS/Text/Chapter-8.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/114_5157_9/OEBPS/Text/Chapter-9.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/115_5157_10/OEBPS/Text/Chapter-10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/116_5157_11/OEBPS/Text/Chapter-11.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/117_5157_12/OEBPS/Text/Chapter-12.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/118_5157_13/OEBPS/Text/Chapter-13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/119_5157_14/OEBPS/Text/Chapter-14.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/120_5157_15/OEBPS/Text/Chapter-15.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_biology/121_5157_16/OEBPS/Text/Chapter-16.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/73_5162_1/OEBPS/Text/Untitled-2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/74_5162_2/OEBPS/Text/Untitled-3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/75_5162_3/OEBPS/Text/Untitled-4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/76_5162_4/OEBPS/Text/Untitled-5.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/77_5162_5/OEBPS/Text/Untitled-6.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/78_5162_6/OEBPS/Text/Untitled-7.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/79_5162_7/OEBPS/Text/Untitled-8.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/80_5162_8/OEBPS/Text/Untitled-9.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/81_5162_9/OEBPS/Text/Untitled-10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/82_5164_10/OEBPS/Text/Untitled-10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/83_5164_11/OEBPS/Text/Untitled-11.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/84_5164_12/OEBPS/Text/Untitled-12.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/85_5164_13/OEBPS/Text/Untitled-13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/86_5164_14/OEBPS/Text/Untitled-14.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/87_5164_15/OEBPS/Text/Untitled-15.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_chemistry/88_5164_16/OEBPS/Text/Untitled-16.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/60_5216_1/OEBPS/Text/Ch-01.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/61_5216_2/OEBPS/Text/Ch-02.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/62_5216_3/OEBPS/Text/Ch-03.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/63_5216_4/OEBPS/Text/Ch-04.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/64_5216_5/OEBPS/Text/Ch-05.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/65_5216_6/OEBPS/Text/Ch-06.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/66_5217_7/OEBPS/Text/Section0002.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/67_5217_8/OEBPS/Text/8.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/68_5217_9/OEBPS/Text/9.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/69_5217_10/OEBPS/Text/10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/70_5217_11/OEBPS/Text/11.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/71_5217_12/OEBPS/Text/12.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_maths/72_5217_13/OEBPS/Text/13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/46_5225_1/OEBPS/Text/Untitled-1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/47_5225_2/OEBPS/Text/Untitled-2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/48_5225_3/OEBPS/Text/Untitled-3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/49_5225_4/OEBPS/Text/Untitled-1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/50_5225_5/OEBPS/Text/Untitled-2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/51_5225_6/OEBPS/Text/Untitled-3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/52_5225_7/OEBPS/Text/Untitled-4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/53_5225_8/OEBPS/Text/Untitled-5.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/54_5227_9/OEBPS/Text/Ch_09.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/55_5227_10/OEBPS/Text/Ch_10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/56_5227_11/OEBPS/Text/Ch_11.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/57_5227_12/OEBPS/Text/Ch_12.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/58_5227_13/OEBPS/Text/Ch_13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_12_physics/59_5227_14/OEBPS/Text/Ch_14.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/68_5236_1/OEBPS/Text/Chapter_1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/69_5236_2/OEBPS/Text/Chapter_2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/70_5236_3/OEBPS/Text/ch3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/71_5236_4/OEBPS/Text/Chapter 4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/72_5236_5/OEBPS/Text/Chapter 5.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/73_5236_6/OEBPS/Text/Chapter 6.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/74_5236_7/OEBPS/Text/Chapter 7.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/75_5236_8/OEBPS/Text/Chapter 8.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/76_5236_9/OEBPS/Text/Chapter 9.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/77_5236_10/OEBPS/Text/ch 10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/78_5236_11/OEBPS/Text/Chapter-11.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/79_5236_12/OEBPS/Text/Chapter-12.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/80_5236_13/OEBPS/Text/Chapter-13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/81_5236_14/OEBPS/Text/Chapter-14.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/82_5236_15/OEBPS/Text/Chapter-15.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_6_science/83_5236_16/OEBPS/Text/Chapter-16.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/50_5237_1/OEBPS/Text/Untitled-1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/51_5237_2/OEBPS/Text/Untitled-2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/52_5237_3/OEBPS/Text/Untitled-3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/53_5237_4/OEBPS/Text/Untitled-4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/54_5237_5/OEBPS/Text/Untitled-5.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/55_5237_6/OEBPS/Text/Untitled-6.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/56_5237_7/OEBPS/Text/Untitled-7.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/57_5237_8/OEBPS/Text/Untitled-8.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/58_5237_9/OEBPS/Text/Untitled-9.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/59_5237_10/OEBPS/Text/Untitled-10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/60_5237_11/OEBPS/Text/Section0001.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/61_5237_12/OEBPS/Text/Untitled-12.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/62_5237_13/OEBPS/Text/chapter-13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/63_5237_14/OEBPS/Text/Untitled-4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/64_5237_15/OEBPS/Text/ch-15.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/65_5237_16/OEBPS/Text/Untitled-1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/66_5237_17/OEBPS/Text/Untitled-13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_7_science/67_5237_18/OEBPS/Text/Untitled-14.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/32_5238_1/OEBPS/Text/Untitled-1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/33_5238_2/OEBPS/Text/ch2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/34_5238_3/OEBPS/Text/ch3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/35_5238_4/OEBPS/Text/ch4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/36_5238_5/OEBPS/Text/ch5.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/37_5238_6/OEBPS/Text/ch6.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/38_5238_7/OEBPS/Text/ch7.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/39_5238_8/OEBPS/Text/8.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/40_5238_9/OEBPS/Text/ch9.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/41_5238_10/OEBPS/Text/ch10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/42_5238_11/OEBPS/Text/ch11.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/43_5238_12/OEBPS/Text/ch12.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/44_5238_13/OEBPS/Text/ch13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/45_5238_14/OEBPS/Text/ch14.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/46_5238_15/OEBPS/Text/ch15.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/47_5238_16/OEBPS/Text/ch16.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/48_5238_17/OEBPS/Text/ch17.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_8_science/49_5238_18/OEBPS/Text/ch18.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/10_5239_10/OEBPS/Text/Untitled-8.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/11_5239_11/OEBPS/Text/Untitled-9.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/12_5239_12/OEBPS/Text/Untitled-10.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/13_5239_13/OEBPS/Text/Untitled-11.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/14_5239_14/OEBPS/Text/Untitled-12.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/15_5239_15/OEBPS/Text/Untitled-13.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/1_5239_1/OEBPS/Text/Untitled-1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/2_5239_2/OEBPS/Text/Untitled-2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/3_5239_3/OEBPS/Text/Untitled-1.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/4_5239_4/OEBPS/Text/Untitled-2.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/5_5239_5/OEBPS/Text/Untitled-3.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/6_5239_6/OEBPS/Text/Untitled-4.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/7_5239_7/OEBPS/Text/Untitled-5.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/8_5239_8/OEBPS/Text/Untitled-6.xhtml
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/9_5239_9/OEBPS/Text/Untitled-7.xhtml
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/16_5240_1/OEBPS/Text/Chapter-1.html
# @@@@@@@@@@@@   HTML parser
# ------- fig  1   --------
# fig + grandparent
# length = 17
# Figure 1.1 Burning of a magnesium ribbon in air and collection of magnesium oxide in a watch-glass
# previous image = ../Images/1219.png
# ------- fig  2   --------
# fig + grandparent
# length = 15
# Figure 1.2 Formation of hydrogen gas by the action of dilute sulphuric acid on zinc
# previous image = ../Images/1293.png
# ------- fig  3   --------
# fig + grandparent
# length = 14
# Figure 1.3 Formation of slaked lime by the reaction of calcium oxide with water
# previous image = ../Images/1462.png
# ------- fig  4   --------
# fig + grandparent
# length = 19
# Figure 1.4 Correct way of heating the boiling tube containing crystals of ferrous sulphate and of smelling the odour
# previous image = ../Images/1553.png
# ------- fig  5   --------
# fig + grandparent
# length = 11
# Figure 1.5 Heating of lead nitrate and emission of nitrogen dioxide
# previous image = ../Images/1542.png
# ------- fig  6   --------
# fig + grandparent
# length = 5
# Figure 1.6 Electrolysis of water
# previous image = ../Images/1637.png
# ------- fig  7   --------
# fig + grandparent
# length = 12
# Figure 1.7 Silver chloride turns grey in sunlight to form silver metal
# previous image = ../Images/1600.png
# ------- fig  8   --------
# fig + grandparent
# length = 10
# Figure 1.8 (a) Iron nails dipped in copper sulphate solution
# previous image = ../Images/1675.png
# ------- fig  9   --------
# fig + grandparent
# length = 15
# Figure 1.8 (b) Iron nails and copper sulphate solutions compared before and after the experiment
# previous image = ../Images/1722.png
# ------- fig  10   --------
# fig + grandparent
# length = 9
# Figure 1.9 Formation of barium sulphate and sodium chloride
# previous image = ../Images/1742.png
# ------- fig  11   --------
# fig + grandparent
# length = 8
# Figure 1.10 Oxidation of copper to copper oxide
# previous image = ../Images/1811.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/17_5240_2/OEBPS/Text/Untitled-4.xhtml
# @@@@@@@@@@@@   XML parser
# ------- fig  1   --------
# fig + grandparent
# length = 16
# Figure 2.1 Reaction of zinc granules with dilute sulphuric acid and testing hydrogen gas by burning
# previous image = ../Images/1291.png
# ------- fig  2   --------
# fig
# length = 6
# Fig. 2.2 and record your observations.
# previous image = ../Images/109.PNG
# ------- fig  3   --------
# fig + grandparent
# length = 10
# Figure 2.2 Passing carbon dioxide gas through calcium hydroxide solution
# previous image = ../Images/1358.png
# ------- fig  4   --------
# fig + grandparent
# length = 8
# Figure 2.3 Acid solution in water conducts electricity
# previous image = ../Images/1461.png
# ------- fig  5   --------
# fig + grandparent
# length = 6
# Figure 2.4 Preparation of HCl gas
# previous image = ../Images/1416.png
# ------- fig  6   --------
# fig + grandparent
# length = 12
# Figure 2.5 Warning sign displayed on containers containing concentrated acids and bases
# previous image = ../Images/1563.png
# ------- fig  7   --------
# fig + grandparent
# length = 15
# Figure 2.6 Variation of pH with the change in concentration of H+(aq) and OH (aq)ions
# previous image = ../Images/1597.png
# ------- fig  8   --------
# fig + grandparent
# length = 18
# Figure 2.7 pH of some common substances shown on a pH paper (colours are only a rough guide)
# previous image = ../Images/1653.png
# ------- fig  9   --------
# fig + grandparent
# length = 8
# Figure 2.8 Important products from the chlor-alkali process
# previous image = ../Images/3113.JPG
# ------- fig  10   --------
# fig + grandparent
# length = 6
# Figure 2.9 Removing water of crystallisation
# previous image = ../Images/1916.png
# ------- fig  11   --------
# fig + grandparent
# length = 23
# Figure 2.10 (a) Ignition tube containing dilute sulphuric acid suspended in a wash-bottle containing sodium hydrogencarbonate, (b) Discharge coming out of the nozzle
# previous image = ../Images/2031.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/18_5240_3/OEBPS/Text/Chapter-3.html
# @@@@@@@@@@@@   HTML parser
# ------- fig  1   --------
# fig + grandparent
# length = 8
# Figure 3.1 Metals are good conductors of heat.
# previous image = ../Images/1234.PNG
# ------- fig  2   --------
# fig + grandparent
# length = 8
# Figure 3.2 Metals are good conductors of electricity.
# previous image = ../Images/1513.png
# ------- fig  3   --------
# fig + grandparent
# length = 8
# Figure 3.3 Action of steam on a metal
# previous image = ../Images/345.PNG
# ------- fig  4   --------
# fig + grandparent
# length = 8
# Figure 3.4 Reaction of metals with salt solutions
# previous image = ../Images/1765.png
# ------- fig  5   --------
#  fig + parent
#  length = 6
# Figure 3.5 Formation of sodium chloride
# previous image = ../Images/e4.png
# ------- fig  6   --------
#  fig + parent
#  length = 6
# Figure 3.6 Formation of magnesium chloride
# previous image = ../Images/e5.png
# ------- fig  7   --------
# fig + grandparent
# length = 9
# Figure 3.7 Heating a salt sample on a spatula
# previous image = ../Images/1883.png
# ------- fig  8   --------
# fig + grandparent
# length = 9
# Figure 3.8 Testing the conductivity of a salt solution
# previous image = ../Images/1898.png
# ------- fig  9   --------
#  fig + parent
#  length = 7
# Figure 3.9 Activity series and related metallurgy
# previous image = ../Images/a.png
# ------- fig  10   --------
# fig + grandparent
# length = 11
# Figure 3.10 Steps involved in the extraction of metals from ores
# previous image = ../Images/1966.png
# ------- fig  11   --------
# fig + grandparent
# length = 8
# Figure 3.11 Thermit process for joining railway tracks
# previous image = ../Images/2041.png
# ------- fig  12   --------
# fig + grandparent
# length = 40
# Figure 3.12 Electrolytic refining of copper. The electrolyte is a solution of acidified copper sulphate. The anode is impure copper, whereas, the cathode is a strip of pure copper. On passing electric current, pure copper is deposited on the cathode.
# previous image = ../Images/2056.png
# ------- fig  13   --------
# fig + grandparent
# length = 36
# Figure 3.13 Investigating the conditions under which iron rusts. In tube A, both air and water are present. In tube B, there is no air dissolved in the water. In tube C, the air is dry.
# previous image = ../Images/x1.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/19_5240_4/OEBPS/Text/Chapter-4.html
# @@@@@@@@@@@@   HTML parser
# ------- fig  1   --------
# fig + grandparent
# length = 6
# Figure 4.1 A molecule of hydrogen
# previous image = ../Images/1580.png
# ------- fig  2   --------
# fig + grandparent
# length = 8
# Figure 4.2 Single bond between two hydrogen atoms
# previous image = ../Images/a.png
# ------- fig  3   --------
# fig + grandparent
# length = 8
# Figure 4.3 Double bond between two oxygen atoms
# previous image = ../Images/1551.png
# ------- fig  4   --------
# fig + grandparent
# length = 8
# Figure 4.4 Triple bond between two nitrogen atoms
# previous image = ../Images/1565.png
# ------- fig  5   --------
# fig + grandparent
# length = 7
# Figure 4.5 Electron dot structure for methane
# previous image = ../Images/1674.png
# ------- fig  6   --------
#  fig + parent
#  length = 11
# Figure 4.6 (a) Carbon atoms linked together with a single bond
# previous image = ../Images/e1.png
# ------- fig  7   --------
# fig + grandparent
# length = 11
# Figure 4.6 (b) Each carbon atom bonded to three hydrogen atoms
# previous image = ../Images/e2.png
# ------- fig  8   --------
# fig + grandparent
# length = 8
# Figure 4.6 (c) Electron dot structure of ethane
# previous image = ../Images/1740.png
# ------- fig  9   --------
# fig + grandparent
# length = 5
# Figure 4.7 Structure of ethene
# previous image = ../Images/1800.png
# ------- fig  10   --------
#  fig + parent
#  length = 6
# Figure 4.8 (a) Two possible carbon-skeletons
# previous image = ../Images/c.png
# ------- fig  11   --------
#  fig + parent
#  length = 11
# Figure 4.8 (b) Complete molecules for two structures with formula C4H10
# previous image = ../Images/2522.png
# ------- fig  12   --------
#  fig + parent
#  length = 11
# Figure 4.9 Structure of cyclohexane (a) carbon skeleton (b) complete molecule
# previous image = ../Images/2546.png
# ------- fig  13   --------
#  fig + parent
#  length = 5
# Figure 4.10 Structure of benzene
# previous image = ../Images/d.png
# ------- fig  14   --------
# fig + grandparent
# length = 5
# Figure 4.11 Formation of ester
# previous image = ../Images/2171.png
# ------- fig  15   --------
# fig + grandparent
# length = 5
# Figure 4.12 Formation of micelles
# previous image = ../Images/2269.png
# ------- fig  16   --------
#  fig + parent
#  length = 7
# Figure 4.13 Effect of soap in cleaning
# previous image = ../Images/2287.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/20_5240_5/OEBPS/Text/Chapter-5.html
# @@@@@@@@@@@@   HTML parser
# ------- fig  1   --------
# fig + grandparent
# length = 55
# Figure 5.1 Imagine you and your friends have found pieces of an old map to reach a treasure. Would it be easy or chaotic to find the way to the treasure? Similar chaos was there in Chemistry as elements were known but there was no clue as to how to classify and study about them.
# previous image = ../Images/942.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/21_5240_6/OEBPS/Text/Chapter-6.html
# @@@@@@@@@@@@   HTML parser
# ------- fig  1   --------
# fig + grandparent
# length = 6
# Figure 6.1 Cross-section of a leaf
# previous image = ../Images/1258.png
# ------- fig  2   --------
# fig + grandparent
# length = 11
# Figure 6.2 Variegated leaf (a) before and (b) after starch test
# previous image = ../Images/1237.png
# ------- fig  3   --------
# fig + grandparent
# length = 9
# Figure 6.3 (a) Open and (b) closed stomatal pore
# previous image = ../Images/11.png
# ------- fig  4   --------
# fig + grandparent
# length = 12
# Figure 6.4 Experimental set-up (a) with potassium hydroxide (b) without potassium hydroxide
# previous image = ../Images/1321.png
# ------- fig  5   --------
# fig + grandparent
# length = 5
# Figure 6.5 Nutrition in Amoeba
# previous image = ../Images/1366.png
# ------- fig  6   --------
# fig + grandparent
# length = 5
# Figure 6.6 Human alimentary canal
# previous image = ../Images/1396.png
# ------- fig  7   --------
# fig + grandparent
# length = 19
# Figure 6.7 (a) Air being passed into lime water with a pichkari/syringe, (b) air being exhaled into lime water
# previous image = ../Images/1468.png
# ------- fig  8   --------
#  fig + parent
#  length = 8
# Figure 6.8 Break-down of glucose by various pathways
# previous image = ../Images/1540.png
# ------- fig  9   --------
# fig + grandparent
# length = 5
# Figure 6.9 Human respiratory system
# previous image = ../Images/man.PNG
# ------- fig  10   --------
# fig + grandparent
# length = 8
# Figure 6.10 Sectional view of the human heart
# previous image = ../Images/1041.PNG
# ------- fig  11   --------
# fig + grandparent
# length = 13
# Figure 6.11 Schematic representation of transport and exchange of oxygen and carbon dioxide
# previous image = ../Images/1735.png
# ------- fig  12   --------
# fig + grandparent
# length = 10
# Figure 6.12 Movement of water during transpiration in a tree
# previous image = ../Images/1792.png
# ------- fig  13   --------
# fig + grandparent
# length = 7
# Figure 6.13 Excretory system in human beings
# previous image = ../Images/6.13_opt.jpeg
# ------- fig  14   --------
# fig + grandparent
# length = 6
# Figure 6.14 Structure of a nephron
# previous image = ../Images/1042.PNG
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/22_5240_7/OEBPS/Text/Chapter-7.html
# @@@@@@@@@@@@   HTML parser
# ------- fig  1   --------
# fig + grandparent
# length = 9
# Figure 7.1 (a) Structure of neuron, (b) Neuromuscular junction
# previous image = ../Images/848.png
# ------- fig  2   --------
# fig + grandparent
# length = 4
# Figure 7.2 Reflex arc
# previous image = ../Images/919.png
# ------- fig  3   --------
# fig + grandparent
# length = 4
# Figure 7.3 Human brain
# previous image = ../Images/959.png
# ------- fig  4   --------
#  fig + parent
#  length = 5
# Figure 7.4 The sensitive plant
# previous image = ../Images/1043.PNG
# ------- fig  5   --------
#  fig + parent
#  length = 11
# Figure 7.5 Response of the plant to the direction of light
# previous image = ../Images/1044.PNG
# ------- fig  6   --------
# fig + grandparent
# length = 5
# Figure 7.6 Plant showing geotropism
# previous image = ../Images/1071.png
# ------- fig  7   --------
# fig + grandparent
# length = 11
# Figure 7.7 Endocrine glands in human beings (a) male, (b) female
# previous image = ../Images/1.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/23_5240_8/OEBPS/Text/Chapter-8.html
# @@@@@@@@@@@@   HTML parser
# ------- fig  1   --------
# fig + grandparent
# length = 6
# Figure 8.2 Multiple fission in Plasmodium
# previous image = ../Images/1052.png
# ------- fig  2   --------
# fig + grandparent
# length = 5
# Figure 8.3 Regeneration in Planaria
# previous image = ../Images/1031.png
# ------- fig  3   --------
#  fig + parent
#  length = 5
# Figure 8.4 Budding in Hydra
# previous image = ../Images/1079.png
# ------- fig  4   --------
# fig + grandparent
# length = 7
# Figure 8.5 Leaf of Bryophyllum with buds
# previous image = ../Images/1194.png
# ------- fig  5   --------
# fig + grandparent
# length = 6
# Figure 8.6 Spore formation in Rhizopus
# previous image = ../Images/1148.png
# ------- fig  6   --------
# fig + grandparent
# length = 6
# Figure 8.7 Longitudinal section of flower
# previous image = ../Images/1255.png
# ------- fig  7   --------
# fig + grandparent
# length = 7
# Figure 8.8 Germination of pollen on stigma
# previous image = ../Images/1233.png
# ------- fig  8   --------
# fig + grandparent
# length = 3
# Figure 8.9 Germination
# previous image = ../Images/1283.png
# ------- fig  9   --------
# fig + grandparent
# length = 6
# Figure 8.10 Human male reproductive system
# previous image = ../Images/1324.png
# ------- fig  10   --------
# fig + grandparent
# length = 6
# Figure 8.11 Human female reproductive system
# previous image = ../Images/1340.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/24_5240_9/OEBPS/Text/Chapter-9.html
# @@@@@@@@@@@@   HTML parser
# ------- fig  1   --------
#  fig + parent
#  length = 2
# Figure 9.1
# previous image = ../Images/1026.png
# ------- fig  2   --------
# ------- fig  2   --------
# fig + grandparent
# length = 45
# Figure 9.2 (a) Free and (b) attached earlobes. The lowest part of the ear, called the earlobe, is closely attached to the side of the head in some of us, and not in others. Free and attached earlobes are two variants found in human populations.
# previous image = ../Images/1103.png
# ------- fig  3   --------
# fig + grandparent
# length = 8
# Figure 9.3 Inheritance of traits over two generations
# previous image = ../Images/1188.png
# ------- fig  4   --------
# fig + grandparent
# length = 2
# Figure 9.4
# previous image = ../Images/1218.png
# ------- fig  5   --------
# fig + grandparent
# length = 13
# Figure 9.5 Independent inheritance of two separate traits, shape and colour of seeds
# previous image = ../Images/1047.PNG
# ------- fig  6   --------
# fig + grandparent
# length = 7
# Figure 9.6 Sex determination in human beings
# previous image = ../Images/1277.png
# ------- fig  7   --------
#  fig + parent
#  length = 9
# Figure 9.7 Variations in a population   inherited and otherwise
# previous image = ../Images/1308.png
# ------- fig  8   --------
# fig + grandparent
# length = 4
# Figure 9.8 Homologous organs
# previous image = ../Images/1511.png
# ------- fig  9   --------
# fig + grandparent
# length = 15
# Figure 9.9 Analogous organs   The wing of a bat and the wing of a bird
# previous image = ../Images/1470.png
# ------- fig  10   --------
# fig + grandparent
# length = 32
# Figure 9.10 Various kind of fossils. Note the different appearances and degrees of detail and preservation. The dinosaur skull fossil shown was found only a few years ago in the Narmada valley.
# previous image = ../Images/1497.png
# ------- fig  11   --------
# fig + grandparent
# length = 18
# Figure 9.11 A flatworm named Planaria has very simple  eyes  that are really just eye-spots which detect light.
# previous image = ../Images/1624.png
# ------- fig  12   --------
# fig + grandparent
# length = 8
# Figure 9.12 Dinosaurs and the evolution of feathers
# previous image = ../Images/1647.png
# ------- fig  13   --------
#  fig + parent
#  length = 6
# Figure 9.13 Evolution of wild cabbage!
# previous image = ../Images/5.png
# ------- fig  14   --------
# fig + grandparent
# length = 6
# Figure 9.14 Evolution  Ladder versus Tree
# previous image = ../Images/1736.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/25_5240_10/OEBPS/Text/Chapter-10.html
# @@@@@@@@@@@@   HTML parser
# ------- fig  1   --------
# fig + grandparent
# length = 12
# Figure 10.1 Schematic representation of spherical mirrors; the shaded side is non-reflecting.
# previous image = ../Images/f1.png
# ------- fig  2   --------
# fig + grandparent
# length = 8
# Figure 10.2 (a) Concave mirror (b) Convex mirror
# previous image = ../Images/1690.png
# ------- fig  3   --------
# fig + grandparent
# length = 2
# Figure 10.4
# previous image = ../Images/f4.png
# ------- fig  4   --------
# fig + grandparent
# length = 2
# Figure 10.5
# previous image = ../Images/f5.png
# ------- fig  5   --------
# fig + grandparent
# length = 2
# Figure 10.6
# previous image = ../Images/f6.png
# ------- fig  6   --------
# fig
# length = 21
# Figure 10.7 illustrates the ray diagrams for the formation of image by a concave mirror for various positions of the object.
# previous image = ../Images/f6.png
# ------- fig  7   --------
#  fig + parent
#  length = 12
# Figure 10.7 Ray diagrams for the image formation by a concave mirror
# previous image = ../Images/1990.png
# ------- fig  8   --------
# fig + grandparent
# length = 9
# Figure 10.8 Formation of image by a convex mirror
# previous image = ../Images/f7.png
# ------- fig  9   --------
# fig + grandparent
# length = 10
# Figure 10.9 The New Cartesian Sign Convention for spherical mirrors
# previous image = ../Images/f8.png
# ------- fig  10   --------
# fig + grandparent
# length = 10
# Figure 10.10 Refraction of light through a rectangular glass slab
# previous image = ../Images/2154.png
# ------- fig  11   --------
# fig + grandparent
# length = 2
# Figure 10.11
# previous image = ../Images/2252.png
# ------- fig  12   --------
# fig + grandparent
# length = 16
# Figure 10.12 (a) Converging action of a convex lens, (b) diverging action of a concave lens
# previous image = ../Images/2346.png
# ------- fig  13   --------
# fig + grandparent
# length = 2
# Figure 10.13
# previous image = ../Images/1048.PNG
# ------- fig  14   --------
# fig + grandparent
# length = 2
# Figure 10.15
# previous image = ../Images/1049.PNG
# ------- fig  15   --------
#  fig + parent
#  length = 22
# Figure 10.16 The position, size and the nature of the image formed by a convex lens for various positions of the object
# previous image = ../Images/2508.png
# ------- fig  16   --------
#  fig + parent
#  length = 15
# Figure 10.17 Nature, position and relative size of the image formed by a concave lens
# previous image = ../Images/2517.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/26_5240_11/OEBPS/Text/Chapter-11.html
# @@@@@@@@@@@@   HTML parser
# ------- fig  1   --------
# fig + grandparent
# length = 5
# Figure 11.1 The human eye
# previous image = ../Images/806.png
# ------- fig  2   --------
# fig + grandparent
# length = 16
# Figure 11.2 (a), (b) The myopic eye, and (c) correction for myopia with a concave lens
# previous image = ../Images/1050.PNG
# ------- fig  3   --------
# fig + grandparent
# length = 28
# Figure 11.3 (a), (b) The hypermetropic eye, and (c) correction for hypermetropia N = Near point of a hypermetropic eye. N  = Near point of a normal eye.
# previous image = ../Images/1051.PNG
# ------- fig  4   --------
# fig + grandparent
# length = 10
# Figure 11.4 Refraction of light through a triangular glass prism
# previous image = ../Images/1052.PNG
# ------- fig  5   --------
# fig + grandparent
# length = 9
# Figure 11.6 Recombination of the spectrum of white light
# previous image = ../Images/1054.PNG
# ------- fig  6   --------
# fig + grandparent
# length = 6
# Figure 11.7 Rainbow in the sky
# previous image = ../Images/1121.png
# ------- fig  7   --------
# fig + grandparent
# length = 4
# Figure 11.8 Rainbow formation
# previous image = ../Images/1055.PNG
# ------- fig  8   --------
# fig + grandparent
# length = 9
# Figure 11.9 Apparent star position due to atmospheric refraction
# previous image = ../Images/1154.png
# ------- fig  9   --------
# fig + grandparent
# length = 9
# Figure 11.10 Atmospheric refraction effects at sunrise and sunset
# previous image = ../Images/1099.png
# ------- fig  10   --------
# fig + grandparent
# length = 10
# Figure 11.12 Reddening of the Sun at sunrise and sunset
# previous image = ../Images/1192.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_10_science/27_5240_12/OEBPS/Text/Chapter-12.html
# @@@@@@@@@@@@   HTML parser
# ------- fig  1   --------
# fig + grandparent
# length = 17
# Figure 12.1 A schematic diagram of an electric circuit comprising   cell, electric bulb, ammeter and plug key
# previous image = ../Images/1105.png
# ------- fig  2   --------
# fig + grandparent
# length = 9
# Figure 12.2 Electric circuit for studying Ohm s law
# previous image = ../Images/16.png
# ------- fig  3   --------
# fig + grandparent
# length = 35
# Figure 12.3 V I graph for a nichrome wire. A straight line plot shows that as the current through a wire increases, the potential difference across the wire increases linearly   this is Ohm s law.
# previous image = ../Images/1248.png
# ------- fig  4   --------
#  fig + parent
#  length = 2
# Figure 12.4
# previous image = ../Images/1276.png
# ------- fig  5   --------
#  fig + parent
#  length = 16
# Figure 12.5 Electric circuit to study the factors on which the resistance of conducting wires depends
# previous image = ../Images/1372.png
# ------- fig  6   --------
#  fig + parent
#  length = 5
# Figure 12.6 Resistors in series
# previous image = ../Images/17.png
# ------- fig  7   --------
# fig
# length = 29
# Figure 12.7 shows a combination of resistors in which three resistors are connected together between points X and Y. Here, the resistors are said to be connected in parallel.
# previous image = ../Images/17.png
# ------- fig  8   --------
#  fig + parent
#  length = 5
# Figure 12.7 Resistors in parallel
# previous image = ../Images/1460.png
# ------- fig  9   --------
# fig + grandparent
# length = 46
# Figure 12.8  Plug the key and measure the potential difference across the first resistor. Let it be V1. Similarly, measure the potential difference across the other two resistors, separately. Let these values be V2 and V3, respectively. Deduce a relationship between V, V1, V2 and V3.
# previous image = ../Images/1508.png
# ------- fig  10   --------
#  fig + parent
#  length = 18
# Figure 12.9 An electric lamp connected in series with a resistor of 4   to a 6 V battery
# previous image = ../Images/1550.png
# ------- fig  11   --------
# fig + grandparent
# length = 2
# Figure 12.10
# previous image = ../Images/1592.png
# ------- fig  12   --------
# fig + grandparent
# length = 32
# Fig. 12.11. Note the ammeter reading, I1. Similarly, measure the currents through R2 and R3. Let these be I2 and I3, respectively. What is the relationship between I, I1, I2 and I3?
# previous image = ../Images/1645.png
# ------- fig  13   --------
# fig + grandparent
# length = 13
# Figure 12.12 An electric circuit showing the combination of series and parallel resistors
# previous image = ../Images/1630.png
# ...
# Fig. 1.8: By applying pressure, particles of matter can be brought close together.
# previous image = ../Images/1100.png
# ------- fig  9   --------
# fig
# length = 9
# Fig. 1.9: Interconversion of the three states of matter
# previous image = ../Images/1125.png
# ------- fig  10   --------
# fig
# length = 14
# Fig. 1.10: A model for converting of solid to liquid and liquid to gas.
# previous image = ../Images/1242.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/2_5239_2/OEBPS/Text/Untitled-2.xhtml
# @@@@@@@@@@@@   XML parser
# ------- fig  1   --------
#  fig + parent
#  length = 5
# Fig. 2.1: Some consumable items
# previous image = ../Images/867.png
# ------- fig  2   --------
#  fig + parent
#  length = 3
# Fig. 2.2: Filtration
# previous image = ../Images/877.png
# ------- fig  3   --------
# fig
# length = 10
# Fig. 2.3: (a) Solution of copper sulphate does not show
# previous image = ../Images/977.png
# ------- fig  4   --------
#  fig + parent
#  length = 5
# Fig. 2.4: The Tyndall effect
# previous image = ../Images/2.4_fmt.jpeg
# ------- fig  5   --------
# fig + grandparent
# length = 44
# Fig. 2.5: Evaporation Is Matter Around Us Pure?  Now answer   What do you think has got evaporated from the watch glass?   Is there a residue on the watch glass?   What is your interpretation? Is ink a single substance (pure) or is it a mixture?
# previous image = ../Images/1036.png
# ------- fig  6   --------
# fig
# length = 6
# Fig. 2.6: Separation of immiscible liquids
# previous image = ../Images/1118.png
# ------- fig  7   --------
#  fig + parent
#  length = 9
# Fig. 2.7: Separation of camphor and salt by sublimation
# previous image = ../Images/1128.png
# ------- fig  8   --------
# fig
# length = 9
# Fig. 2.8: Separation of dyes in black ink using
# previous image = ../Images/1165.png
# ------- fig  9   --------
# fig
# length = 8
# Fig.2.9: Separation of two miscible liquids by distillation
# previous image = ../Images/1150.png
# ------- fig  10   --------
#  fig + parent
#  length = 4
# Fig. 2.10: Fractional distillation
# previous image = ../Images/1223.png
# ------- fig  11   --------
# fig
# length = 12
# Fig. 2.11: Flow diagram shows the process of obtaining gases from air
# previous image = ../Images/1237.png
# ------- fig  12   --------
# fig
# length = 7
# Fig. 2.12: Separation of components of air
# previous image = ../Images/1198.png
# ------- fig  13   --------
# fig
# length = 8
# Fig. 2.13: Water purification system in water works
# previous image = ../Images/1290.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/3_5239_3/OEBPS/Text/Untitled-1.xhtml
# @@@@@@@@@@@@   XML parser
# ------- fig  1   --------
# fig
# length = 17
# Fig. 3.1: Ignition tube containing solution of X, dipped in a conical flask containing solution of Y.
# previous image = ../Images/695.png
# ------- fig  2   --------
# fig
# length = 9
# Fig. 3.2: An image of the surface of silicon
# previous image = ../Images/3.2_fmt.jpeg
# ------- fig  3   --------
# fig
# length = 10
# Fig. 3.3: Symbols for some elements as proposed by Dalton
# previous image = ../Images/779.png
# ------- fig  4   --------
# fig
# length = 25
# Fig. 3.4 : (a) Watermelon, (b) 12 pieces, (c) 1/12 of watermelon, (d) how the fruit seller can weigh the fruits using pieces of watermelon
# previous image = ../Images/856.png
# ------- fig  5   --------
# fig
# length = 9
# Fig. 3.5: Relationship between mole, Avogadro number and mass
# previous image = ../Images/1068.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/4_5239_4/OEBPS/Text/Untitled-2.xhtml
# @@@@@@@@@@@@   XML parser
# ------- fig  1   --------
# fig
# length = 6
# Fig.4.1: Thomson s model of an atom
# previous image = ../Images/836.png
# ------- fig  2   --------
# fig
# length = 9
# Fig. 4.2: Scattering of  -particles by a gold foil
# previous image = ../Images/998.png
# ------- fig  3   --------
# fig
# length = 9
# Fig. 4.3: A few energy levels in an atom
# previous image = ../Images/969.png
# ------- fig  4   --------
# fig
# length = 9
# Fig.4.4: Schematic atomic structure of the first eighteen elements
# previous image = ../Images/1091.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/5_5239_5/OEBPS/Text/Untitled-3.xhtml
# @@@@@@@@@@@@   XML parser
# ------- fig  1   --------
#  fig + parent
#  length = 4
# Fig. 5.1: Compound microscope
# previous image = ../Images/d1.PNG
# ------- fig  2   --------
# fig
# length = 7
# Fig. 5.2: Cells of an onion peel
# previous image = ../Images/d2.PNG
# ------- fig  3   --------
# fig
# length = 8
# Fig. 5.3: Various cells from the human body
# previous image = ../Images/d3.PNG
# ------- fig  4   --------
#  fig + parent
#  length = 4
# Fig. 5.4: Prokaryotic cell
# previous image = ../Images/d4.PNG
# ------- fig  5   --------
#  fig + parent
#  length = 4
# Fig. 5.5: Animal cell
# previous image = ../Images/d6.PNG
# ------- fig  6   --------
#  fig + parent
#  length = 4
# Fig. 5.6: Plant cell
# previous image = ../Images/d7.PNG
# ------- fig  7   --------
# fig + grandparent
# length = 3
# Fig. 5.7: Mitosis
# previous image = ../Images/d8.PNG
# ------- fig  8   --------
#  fig + parent
#  length = 3
# Fig. 5.8: Meiosis
# previous image = ../Images/d9.PNG
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/6_5239_6/OEBPS/Text/Untitled-4.xhtml
# @@@@@@@@@@@@   XML parser
# ------- fig  1   --------
# fig
# length = 8
# Fig. 6.1: Growth of roots in onion bulbs
# previous image = ../Images/2870.png
# ------- fig  2   --------
# fig
# length = 9
# Fig. 6.2: Location of meristematic tissue in plant body
# previous image = ../Images/d10.PNG
# ------- fig  3   --------
#  fig + parent
#  length = 16
# Fig. 6.4: Various types of simple tissues: (a) Parenchyma (b) Collenchyma (c) Sclerenchyma (i) transverse section,
# previous image = ../Images/d12.PNG
# ------- fig  4   --------
# fig
# length = 13
# Fig. 6.5: Guard cells and epidermal cells: (a) lateral view, (b) surface view
# previous image = ../Images/d13.PNG
# ------- fig  5   --------
#  fig + parent
#  length = 4
# Fig. 6.6: Protective tissue
# previous image = ../Images/d14.PNG
# ------- fig  6   --------
# fig
# length = 6
# Fig. 6.7: Types of complex tissue
# previous image = ../Images/d15.PNG
# ------- fig  7   --------
# fig
# length = 6
# Fig. 6.8: Location of muscle fibres
# previous image = ../Images/d16.PNG
# ------- fig  8   --------
# fig
# length = 7
# Fig. 6.9: Different types of epithelial tissues
# previous image = ../Images/d17.PNG
# ------- fig  9   --------
# fig
# length = 23
# Fig. 6.10: Types of connective tissues: (a) types of blood cells, (b) compact bone, (c) hyaline cartilage, (d) areolar tissue, (e) adipose tissue
# previous image = ../Images/d18.PNG
# ------- fig  10   --------
# fig
# length = 15
# Fig. 6.11: Types of muscles fibres: (a) striated muscle, (b) smooth muscle, (c) cardiac muscle
# previous image = ../Images/d21.PNG
# ------- fig  11   --------
# fig
# length = 6
# Fig. 6.12: Neuron-unit of nervous tissue
# previous image = ../Images/d20.PNG
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/7_5239_7/OEBPS/Text/Untitled-5.xhtml
# @@@@@@@@@@@@   XML parser
# ------- fig  1   --------
#  fig + parent
#  length = 3
# Fig. 7.1: Monera
# previous image = ../Images/d22.PNG
# ------- fig  2   --------
#  fig + parent
#  length = 3
# Fig. 7.2: Protozoa
# previous image = ../Images/d23.PNG
# ------- fig  3   --------
#  fig + parent
#  length = 3
# Fig. 7.3: Fungi
# previous image = ../Images/d24.PNG
# ------- fig  4   --------
# fig
# length = 6
# Fig. 7.4: The Five Kingdom classification
# previous image = ../Images/d25.PNG
# ------- fig  5   --------
#  fig + parent
#  length = 4
# Fig. 7.5: Thallophyta   Algae
# previous image = ../Images/d26.PNG
# ------- fig  6   --------
#  fig + parent
#  length = 5
# Fig. 7.6: Some common bryophytes
# previous image = ../Images/d27.PNG
# ------- fig  7   --------
#  fig + parent
#  length = 3
# Fig. 7.7: Pteridophyta
# previous image = ../Images/d28.PNG
# ------- fig  8   --------
#  fig + parent
#  length = 3
# Fig. 7.8: Gymnosperms
# previous image = ../Images/d29.PNG
# ------- fig  9   --------
#  fig + parent
#  length = 3
# Fig. 7.9: Monocot
# previous image = ../Images/d30.PNG
# ------- fig  10   --------
#  fig + parent
#  length = 3
# Fig. 7.10: Dicot
# previous image = ../Images/d31.PNG
# ------- fig  11   --------
#  fig + parent
#  length = 5
# Fig. 7.11: Classification of plants
# previous image = ../Images/d32.PNG
# ------- fig  12   --------
#  fig + parent
#  length = 3
# Fig. 7.12: Porifera
# previous image = ../Images/d33.PNG
# ------- fig  13   --------
#  fig + parent
#  length = 3
# Fig. 7.13: Coelenterata
# previous image = ../Images/d34.PNG
# ------- fig  14   --------
#  fig + parent
#  length = 3
# Fig. 7.14: Platyhelminthes
# previous image = ../Images/d35.PNG
# ------- fig  15   --------
#  fig + parent
#  length = 4
# Fig. 7.15: Nematoda (Aschelminthes)
# previous image = ../Images/d36.PNG
# ------- fig  16   --------
#  fig + parent
#  length = 3
# Fig. 7.16: Annelida
# previous image = ../Images/d37.PNG
# ------- fig  17   --------
#  fig + parent
#  length = 3
# Fig. 7.17: Arthropoda
# previous image = ../Images/d38.PNG
# ------- fig  18   --------
#  fig + parent
#  length = 3
# Fig. 7.18: Mollusca
# previous image = ../Images/d40.PNG
# ------- fig  19   --------
#  fig + parent
#  length = 3
# Fig. 7.19: Echinodermata
# previous image = ../Images/d41.PNG
# ------- fig  20   --------
#  fig + parent
#  length = 4
# Fig. 7.20: Protochordata: Balanoglossus
# previous image = ../Images/d42.PNG
# ------- fig  21   --------
# fig
# length = 6
# Fig. 7.21: A jawless vertebrate: Petromyzon
# previous image = ../Images/d43.PNG
# ------- fig  22   --------
#  fig + parent
#  length = 4
# Fig. 7.22 (a): Pisces
# previous image = ../Images/d44.PNG
# ------- fig  23   --------
#  fig + parent
#  length = 4
# Fig. 7.22 (b): Pisces
# previous image = ../Images/d45.PNG
# ------- fig  24   --------
#  fig + parent
#  length = 3
# Fig. 7.23: Amphibia
# previous image = ../Images/d46.PNG
# ------- fig  25   --------
#  fig + parent
#  length = 3
# Fig. 7.24: Reptilia
# previous image = ../Images/d47.PNG
# ------- fig  26   --------
#  fig + parent
#  length = 4
# Fig. 7.25: Aves (birds)
# previous image = ../Images/d48.PNG
# ------- fig  27   --------
#  fig + parent
#  length = 3
# Fig. 7.26: Mammalia
# previous image = ../Images/d49.PNG
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/8_5239_8/OEBPS/Text/Untitled-6.xhtml
# @@@@@@@@@@@@   XML parser
# ------- fig  1   --------
# fig
# length = 11
# Fig. 8.1: Positions of an object on a straight line path
# previous image = ../Images/838.png
# ------- fig  2   --------
# fig
# length = 11
# Fig. 8.3: Distance-time graph of an object moving with uniform speed
# previous image = ../Images/1050.png
# ------- fig  3   --------
# fig
# length = 9
# Fig. 8.4: Distance-time graph for a car moving with
# previous image = ../Images/1075.png
# ------- fig  4   --------
# fig
# length = 10
# Fig. 8.5: Velocity-time graph for uniform motion of a car
# previous image = ../Images/1090.png
# ------- fig  5   --------
# fig
# length = 11
# Fig. 8.6: Velocity-time graph for a car moving with uniform accelerations.
# previous image = ../Images/1214.png
# ------- fig  6   --------
# fig
# length = 11
# Fig. 8.7: Velocity-time graphs of an object in non-uniformly accelerated motion.
# previous image = ../Images/d12.PNG
# ------- fig  7   --------
# fig
# length = 43
# Fig. 8.7 (b) shows the velocity-time graph representing the non-uniform variation of velocity of the object with time. Try to interpret these graphs.
# previous image = ../Images/d12.PNG
# ------- fig  8   --------
# fig
# length = 8
# Fig. 8.8: Velocity-time graph to obtain the equations
# previous image = ../Images/1200.png
# ------- fig  9   --------
#  fig + parent
#  length = 13
# Fig. 8.9: The motion of an athlete along closed tracks of different shapes.
# previous image = ../Images/d21.PNG
# ------- fig  10   --------
#  fig + parent
#  length = 14
# Fig. 8.10: A stone describing a circular path with a velocity of constant magnitude.
# previous image = ../Images/1355.png
# ------- fig  11   --------
# fig
# length = 20
# Fig 8.11 shows the distance-time graph of three objects A,B and C. Study the graph and answer the following questions:
# previous image = ../Images/1355.png
# ------- fig  12   --------
#  fig + parent
#  length = 2
# Fig. 8.11
# previous image = ../Images/1403.png
# ------- fig  13   --------
#  fig + parent
#  length = 2
# Fig. 8.12
# previous image = ../Images/1417.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
#
# ++++++++++++++++++++++++++++   START   +++++++++++++++++++++
# C:/Users/gopis/Desktop/mtp2code/data/e_pathshala_epub/class_9_science/9_5239_9/OEBPS/Text/Untitled-7.xhtml
# @@@@@@@@@@@@   XML parser
# ------- fig  1   --------
# fig
# length = 12
# Fig. 9.1: Pushing, pulling, or hitting objects change their state of motion.
# previous image = ../Images/910.png
# ------- fig  2   --------
#  fig + parent
#  length = 23
# Fig. 9.2: (a) A spring expands on application of force; (b) A spherical rubber ball becomes oblong as we apply force on it.
# previous image = ../Images/961.png
# ------- fig  3   --------
# ------- fig  3   --------
# fig
# length = 9
# Fig. 9.3: Two forces acting on a wooden block
# previous image = ../Images/983.png
# ------- fig  4   --------
#  fig + parent
#  length = 2
# Fig. 9.4
# previous image = ../Images/996.png
# ------- fig  5   --------
# fig
# length = 24
# Fig. 9.5: (a) the downward motion; (b) the upward motion of a marble on an inclined plane; and (c) on a double inclined plane.
# previous image = ../Images/1105.png
# ------- fig  6   --------
# fig + grandparent
# length = 24
# Fig. 9.6: Only the carom coin at the bottom of a pile is removed when a fast moving carom coin (or striker) hits it.
# previous image = ../Images/1134.png
# ------- fig  7   --------
# fig
# length = 19
# Fig. 9.7: When the card is flicked with the finger the coin placed over it falls in the  tumbler.
# previous image = ../Images/1179.png
# ------- fig  8   --------
#  fig + parent
#  length = 16
# Fig. 9.8: A fielder pulls his hands gradually with the moving ball while holding a catch.
# previous image = ../Images/1225.png
# ------- fig  9   --------
#  fig + parent
#  length = 2
# Fig. 9.9
# previous image = ../Images/1237.png
# ------- fig  10   --------
#  fig + parent
#  length = 10
# Fig. 9.10: Action and reaction forces are equal and opposite.
# previous image = ../Images/1279.png
# ------- fig  11   --------
#  fig + parent
#  length = 13
# Fig. 9.11: A forward force on the bullet and recoil of the gun.
# previous image = ../Images/1288.png
# ------- fig  12   --------
# fig
# length = 13
# Fig. 9.12: As the sailor jumps in forward direction, the boat moves backwards.
# previous image = ../Images/1302.png
# ------- fig  13   --------
#  fig + parent
#  length = 2
# Fig. 9.13
# previous image = ../Images/1317.png
# ------- fig  14   --------
# fig
# length = 10
# Fig. 9.14: Conservation of momentum in collision of two balls.
# previous image = ../Images/1330.png
# ------- fig  15   --------
# fig + grandparent
# length = 2
# Fig. 9.15
# previous image = ../Images/1380.png
# ------- fig  16   --------
# fig + grandparent
# length = 21
# Fig. 9.16   Also, observe the difference in the velocity the cork appears to have and that of the recoiling test tube.
# previous image = ../Images/1393.png
# ------- fig  17   --------
# fig
# length = 6
# Fig. 9.17: Recoil of a pistol
# previous image = ../Images/1408.png
# ------- fig  18   --------
# fig
# length = 8
# Fig. 9.18: The girl jumps onto the cart.
# previous image = ../Images/1426.png
# ------- fig  19   --------
# fig
# length = 15
# Fig. 9.19: A collision of two hockey players: (a) before collision and (b) after collision.
# previous image = ../Images/1473.png
# ++++++++++++++++++++++++++++   END   +++++++++++++++++++++
